# %% [markdown]
# <a href="https://colab.research.google.com/github/xieruishen/Atari_with_RL/blob/main/Simple_Path_Finding_with_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### Macros for Initialization Path Finding Board Configuration

# %%
BOARD_ROWS = 15
BOARD_COLS = 15
WIN_STATE = (14, 14) # location of goal
START_STATE = (0, 0)
OBSTACLES = [(1, 4), (2, 3), (2,7), (2, 8), (3, 1), (3, 7), (4,0), (4, 5), (5, 5), 
             (5, 12), (5, 13), (5, 14), (6,5),(6, 6), (9,9), (9, 10), (9, 11), 
             (9, 12), (10, 0), (10, 1), (10, 4), (11, 12), (12, 4), (12, 13), (13, 14)]

# %% [markdown]
# ### Parameters for Reinforcement Learning

# %%
LEARNING_RATE = 0.6
EXPLORE_RATE = 0.4
GAMMA_DECAY = 0.5

# %% [markdown]
# ### Set Up Board Environment for Path Finding

# %%
class BoardState:
    def __init__(self, state=START_STATE, obstacles=OBSTACLES):
        self.board = np.zeros([BOARD_ROWS, BOARD_COLS])
        self.obstacles = obstacles
        # mark obstacles on the board
        for obstacle in obstacles:
          self.board[obstacle[0], obstacle[1]] = -1
        self.board[WIN_STATE[0], WIN_STATE] = 1

        self.state = state # start with starting location
        self.deterministic = False
    
    def checkObstacle(self, state):
        """
          Function to check if a certain location is an obstacle
        """
        return self.board[state[0], state[1]] == -1
        
    def giveReward(self, next_state, cur_state):
        """
          Reward function for going into a given state: R(s,a, s') where s' is the next state
        """
        if next_state == WIN_STATE:
            return 10
        elif self.checkObstacle(next_state):
            return -3
        else:
            # calculate manhattan distance to goal
            next_state_distance = abs(WIN_STATE[0] - next_state[0]) + abs(WIN_STATE[1] - next_state[1])
            cur_state_distance = abs(WIN_STATE[0] - cur_state[0]) + abs(WIN_STATE[1] - cur_state[1])
            if next_state_distance <= cur_state_distance:
              return 3
            else:
              return 2
    
    def checkReachEnd(self):
        return self.state == WIN_STATE

    def _chooseActionProb(self, action):
        other_actions_p = (1 - DETERMINISTIC_Rate)/2
        if action == "up":
            return np.random.choice(["up", "left", "right"], p=[DETERMINISTIC_Rate, other_actions_p, other_actions_p])
        if action == "down":
            return np.random.choice(["down", "left", "right"], p=[DETERMINISTIC_Rate, other_actions_p, other_actions_p])
        if action == "left":
            return np.random.choice(["left", "up", "down"], p=[DETERMINISTIC_Rate, other_actions_p, other_actions_p])
        if action == "right":
            return np.random.choice(["right", "up", "down"], p=[DETERMINISTIC_Rate, other_actions_p, other_actions_p])
    
    def checkAtTopBoundary(self):
        return self.state[0] == 0 
    
    def checkAtBottomBoundary(self):
        return self.state[0] == BOARD_ROWS-1
    
    def checkAtLeftBoundary(self):
        return self.state[1] == 0
    
    def checkAtRightBoundary(self):
        return self.state[1] == BOARD_COLS-1
    
    def checkActionValid(self, action):
        actions_legal = ["up", "down", "left", "right"]
        if self.checkAtTopBoundary():
          actions_legal.remove("up")
        if self.checkAtBottomBoundary():
          actions_legal.remove("down")
        if self.checkAtLeftBoundary():
          actions_legal.remove("left")
        if self.checkAtRightBoundary():
          actions_legal.remove("right")

        if action not in actions_legal:
          action = np.random.choice(actions_legal)
        
        return action
        
    def nextPosition(self, action):
        """
        action: up, down, left, right
        return next position on board
        """
        if action == "up":
            nextState = (self.state[0]-1, self.state[1])
        elif action == "down":
            nextState = (self.state[0]+1, self.state[1])
        elif action == "left":
            nextState = (self.state[0], self.state[1]-1)
        else:
            nextState = (self.state[0], self.state[1]+1)
        return nextState
    
    def printBoard(self):
        # current position
        self.board[START_STATE[0], START_STATE[1]] = 1
        for i in range(0, BOARD_ROWS):
            print('--------------------------------------------------------------')
            out = '| '
            for j in range(0, BOARD_COLS):
                if self.board[i, j] == 1:
                    token = '*'
                elif self.board[i, j] == -1:
                    token = 'x'
                elif self.board[i, j] == 0:
                    token = ' '
                if i == self.state[0] and j == self.state[1]:
                    token = 'p'
                out += token + ' | '
            print(out)
        print('--------------------------------------------------------------')
    
    def printPath(self, path):
        # current position
        self.board[START_STATE[0], START_STATE[1]] = 1
        self.board[WIN_STATE[0], WIN_STATE[1]] = 2
        for i in range(0, BOARD_ROWS):
            print('--------------------------------------------------------------')
            out = '| '
            for j in range(0, BOARD_COLS):
                if self.board[i, j] == 1:
                    token = 'S'
                elif self.board[i, j] == 2:
                    token = 'G'
                elif self.board[i, j] == -1:
                    token = 'x'
                elif self.board[i, j] == 0:
                    token = ' '
                if (i, j) in path:
                    token = 'p'
                out += token + ' | '
            print(out)
        print('--------------------------------------------------------------')

# %% [markdown]
# ### Initialize Board Environment
# p: starting position
# x: obstacles
# *: goal

# %%
board = BoardState()
board.printBoard()
# Out:
# --------------------------------------------------------------
# | p |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   | x |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   | x |   |   |   | x | x |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   | x |   |   |   |   |   | x |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# | x |   |   |   |   | x |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   |   | x |   |   |   |   |   |   | x | x | x |
# --------------------------------------------------------------
# |   |   |   |   |   | x | x |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   |   |   | x | x | x | x |   |   |
# --------------------------------------------------------------
# | x | x |   |   | x |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   |   |   |   |   |   | x |   |   |
# --------------------------------------------------------------
# |   |   |   |   | x |   |   |   |   |   |   |   |   | x |   |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   | x |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   |   |   |   |   |   |   |   | * |
# --------------------------------------------------------------

# %% [markdown]
# ### Path Finding Agent

# %%
class Agent:
    def __init__(self):
        self.states = []  # record all (position, action) taken
        self.states_num_per_round = []
        self.runtime_per_round = []
        self.actions = ["up", "down", "left", "right"]
        self.boardState = BoardState()
        self.reachGoal = self.boardState.checkReachEnd()
        self.lr = LEARNING_RATE
        self.exp_rate = EXPLORE_RATE 
        self.decay_gamma = GAMMA_DECAY

        # initial Q values
        self.Q_values = {}
        for i in range(BOARD_ROWS):
            for j in range(BOARD_COLS):
                self.Q_values[(i, j)] = {}
                for a in self.actions:
                    if (i == 0 and a == "up") or (
                        i == BOARD_ROWS-1 and a == "down") or (
                            j == 0 and a == "left") or (
                                j == BOARD_COLS-1 and a == "right"):
                      self.Q_values[(i, j)][a] = -math.inf
                    else:
                      self.Q_values[(i, j)][a] = 0  
    
    def chooseAction(self):
        # choose action with most expected value/maximum reward
        max_next_reward = 0
        action = ""
        
        if np.random.uniform(0, 1) <= self.exp_rate:
            action = np.random.choice(self.actions)
        else:
            # greedy action
            for a in self.actions:
                current_position = self.boardState.state
                next_reward = self.Q_values[current_position][a]
                if next_reward >= max_next_reward:
                    action = a
                    max_next_reward = next_reward
        action = self.boardState.checkActionValid(action)
        return action
    
    def takeAction(self, action):
        position = self.boardState.nextPosition(action)
        # update State
        self.boardState.state = position     
    
    def reset(self):
        self.states = []
        self.boardState = BoardState()
        self.reachGoal = self.boardState.checkReachEnd()
    
    def play(self, rounds=10):
        i = 0
        start_time = time.time()
        while i < rounds:
            # to the end of game back propagate reward
            print("round: ", i)
            if self.boardState.checkReachEnd():
                # update Q table for end state
                next_optimal_state_qValue = 0
                next_state = WIN_STATE

                # back propagate
                for s in reversed(self.states): # s is a state-action pair
                    current_q_value = self.Q_values[s[0]][s[1]]
                    # update Q value for current state 
                    action_reward = self.boardState.giveReward(next_state, s[0]) # R(s,a,s')
                    # next_state_reward = R(s,a,s') + y*[max_a' Q(s', a')]
                    future_rewards = action_reward + self.decay_gamma*next_optimal_state_qValue 
                    # Q_(k+1)(s,a) = Q_k(s,a) + lr*(next_state_reward - Q_k(s,a)) 
                    updated_q_value = current_q_value + self.lr*(future_rewards - current_q_value)
                    self.Q_values[s[0]][s[1]] = updated_q_value
                    
                    next_state = s[0]
                    next_optimal_state_qValue = updated_q_value

                # reset board and restart another round
                self.states_num_per_round.append(len(self.states))    
                self.reset()
                i += 1
                finish_time = time.time()
                self.runtime_per_round.append(finish_time - start_time) 
                start_time = finish_time
            else:
                action = self.chooseAction()
                # append traces of actions agent has taken
                self.states.append([(self.boardState.state), action])
                print("current position {} action {}".format(self.boardState.state, action))
                #self.boardState.printBoard()
                #print("states: ", self.states)
                # By taking the action, agent reaches the next state
                self.takeAction(action)
                print("next state", self.boardState.state)
                print("*********************************************************")
                self.reachGoal = self.boardState.checkReachEnd()
      
    def get_result_path(self):
        path = []
        current_position = (0,0)
        while current_position != WIN_STATE:
          print("current position: ", current_position)
          path.append(current_position)
          max_next_reward = -math.inf
          action = ""
          for a in self.actions:
              next_reward = self.Q_values[current_position][a]
              if next_reward >= max_next_reward:
                  action = a
                  max_next_reward = next_reward
    
          if action == "up":
              next_position = (current_position[0]-1, current_position[1])
          elif action == "down":
              next_position = (current_position[0]+1, current_position[1])
          elif action == "left":
              next_position = (current_position[0], current_position[1]-1)
          else:
              next_position = (current_position[0], current_position[1]+1)
          current_position = next_position
        return path
      
    def plot_runtime(self):
        plt.plot(self.runtime_per_round)
        plt.ylabel('runtime (seconds)')
        plt.xlabel('round number')
        title = "learning rate: {lr}, gamma decay: {gamma}".format(lr = LEARNING_RATE, gamma = GAMMA_DECAY)
        plt.title(title)
        plt.show()

    def plot_states_num_per_round(self):
        plt.plot(self.states_num_per_round)
        plt.ylabel('number of states taken to reach goal')
        plt.xlabel('round number')
        title = "learning rate: {lr}, gamma decay: {gamma}".format(lr = LEARNING_RATE, gamma = GAMMA_DECAY)
        plt.title(title)
        plt.show()

# %% [markdown]
# ### Start Path Finding

# %%
path_agent = Agent()
path_agent.Q_values
# Out:
# {(0, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': -inf},
#  (0, 1): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 2): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 3): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 4): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 5): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 6): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 7): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 8): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 9): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 10): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 11): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 12): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 13): {'down': 0, 'left': 0, 'right': 0, 'up': -inf},
#  (0, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': -inf},
#  (1, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (1, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (1, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (2, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (2, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (2, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (3, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (3, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (3, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (4, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (4, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (4, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (5, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (5, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (5, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (6, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (6, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (6, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (7, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (7, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (7, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (8, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (8, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (9, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (9, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (10, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (10, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (10, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (11, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (11, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (11, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (12, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (12, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (12, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (13, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (13, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 2): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 3): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 4): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 5): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 6): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 7): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 8): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 9): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 10): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 11): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 12): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 13): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (13, 14): {'down': 0, 'left': 0, 'right': -inf, 'up': 0},
#  (14, 0): {'down': -inf, 'left': -inf, 'right': 0, 'up': 0},
#  (14, 1): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 2): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 3): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 4): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 5): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 6): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 7): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 8): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 9): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 10): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 11): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 12): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 13): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 14): {'down': -inf, 'left': 0, 'right': -inf, 'up': 0}}

# %%
path_agent.play(300)
# Out:
# Streaming output truncated to the last 5000 lines.
# current position (6, 10) action right
# next state (6, 11)
# *********************************************************
# round:  283
# current position (6, 11) action right
# next state (6, 12)
# *********************************************************
# round:  283
# current position (6, 12) action down
# next state (7, 12)
# *********************************************************
# round:  283
# current position (7, 12) action up
# next state (6, 12)
# *********************************************************
# round:  283
# current position (6, 12) action down
# next state (7, 12)
# *********************************************************
# round:  283
# current position (7, 12) action right
# next state (7, 13)
# *********************************************************
# round:  283
# current position (7, 13) action left
# next state (7, 12)
# *********************************************************
# round:  283
# current position (7, 12) action down
# next state (8, 12)
# *********************************************************
# round:  283
# current position (8, 12) action right
# next state (8, 13)
# *********************************************************
# round:  283
# current position (8, 13) action right
# next state (8, 14)
# *********************************************************
# round:  283
# current position (8, 14) action down
# next state (9, 14)
# *********************************************************
# round:  283
# current position (9, 14) action up
# next state (8, 14)
# *********************************************************
# round:  283
# current position (8, 14) action down
# next state (9, 14)
# *********************************************************
# round:  283
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  283
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  283
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  283
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action left
# next state (11, 13)
# *********************************************************
# round:  283
# current position (11, 13) action up
# next state (10, 13)
# *********************************************************
# round:  283
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  283
# current position (10, 14) action up
# next state (9, 14)
# *********************************************************
# round:  283
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  283
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action left
# next state (11, 13)
# *********************************************************
# round:  283
# current position (11, 13) action up
# next state (10, 13)
# *********************************************************
# round:  283
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  283
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action left
# next state (11, 13)
# *********************************************************
# round:  283
# current position (11, 13) action up
# next state (10, 13)
# *********************************************************
# round:  283
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  283
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  283
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action down
# next state (13, 14)
# *********************************************************
# round:  283
# current position (13, 14) action up
# next state (12, 14)
# *********************************************************
# round:  283
# current position (12, 14) action left
# next state (12, 13)
# *********************************************************
# round:  283
# current position (12, 13) action left
# next state (12, 12)
# *********************************************************
# round:  283
# current position (12, 12) action up
# next state (11, 12)
# *********************************************************
# round:  283
# current position (11, 12) action down
# next state (12, 12)
# *********************************************************
# round:  283
# current position (12, 12) action down
# next state (13, 12)
# *********************************************************
# round:  283
# current position (13, 12) action up
# next state (12, 12)
# *********************************************************
# round:  283
# current position (12, 12) action down
# next state (13, 12)
# *********************************************************
# round:  283
# current position (13, 12) action up
# next state (12, 12)
# *********************************************************
# round:  283
# current position (12, 12) action down
# next state (13, 12)
# *********************************************************
# round:  283
# current position (13, 12) action right
# next state (13, 13)
# *********************************************************
# round:  283
# current position (13, 13) action right
# next state (13, 14)
# *********************************************************
# round:  283
# current position (13, 14) action down
# next state (14, 14)
# *********************************************************
# round:  283
# round:  284
# current position (0, 0) action right
# next state (0, 1)
# *********************************************************
# round:  284
# current position (0, 1) action right
# next state (0, 2)
# *********************************************************
# round:  284
# current position (0, 2) action down
# next state (1, 2)
# *********************************************************
# round:  284
# current position (1, 2) action up
# next state (0, 2)
# *********************************************************
# round:  284
# current position (0, 2) action right
# next state (0, 3)
# *********************************************************
# round:  284
# current position (0, 3) action left
# next state (0, 2)
# *********************************************************
# round:  284
# current position (0, 2) action right
# next state (0, 3)
# *********************************************************
# round:  284
# current position (0, 3) action right
# next state (0, 4)
# *********************************************************
# round:  284
# current position (0, 4) action right
# next state (0, 5)
# *********************************************************
# round:  284
# current position (0, 5) action right
# next state (0, 6)
# *********************************************************
# round:  284
# current position (0, 6) action right
# next state (0, 7)
# *********************************************************
# round:  284
# current position (0, 7) action left
# next state (0, 6)
# *********************************************************
# round:  284
# current position (0, 6) action right
# next state (0, 7)
# *********************************************************
# round:  284
# current position (0, 7) action right
# next state (0, 8)
# *********************************************************
# round:  284
# current position (0, 8) action right
# next state (0, 9)
# *********************************************************
# round:  284
# current position (0, 9) action right
# next state (0, 10)
# *********************************************************
# round:  284
# current position (0, 10) action left
# next state (0, 9)
# *********************************************************
# round:  284
# current position (0, 9) action right
# next state (0, 10)
# *********************************************************
# round:  284
# current position (0, 10) action right
# next state (0, 11)
# *********************************************************
# round:  284
# current position (0, 11) action down
# next state (1, 11)
# *********************************************************
# round:  284
# current position (1, 11) action down
# next state (2, 11)
# *********************************************************
# round:  284
# current position (2, 11) action up
# next state (1, 11)
# *********************************************************
# round:  284
# current position (1, 11) action right
# next state (1, 12)
# *********************************************************
# round:  284
# current position (1, 12) action down
# next state (2, 12)
# *********************************************************
# round:  284
# current position (2, 12) action down
# next state (3, 12)
# *********************************************************
# round:  284
# current position (3, 12) action right
# next state (3, 13)
# *********************************************************
# round:  284
# current position (3, 13) action right
# next state (3, 14)
# *********************************************************
# round:  284
# current position (3, 14) action down
# next state (4, 14)
# *********************************************************
# round:  284
# current position (4, 14) action left
# next state (4, 13)
# *********************************************************
# round:  284
# current position (4, 13) action right
# next state (4, 14)
# *********************************************************
# round:  284
# current position (4, 14) action up
# next state (3, 14)
# *********************************************************
# round:  284
# current position (3, 14) action down
# next state (4, 14)
# *********************************************************
# round:  284
# current position (4, 14) action left
# next state (4, 13)
# *********************************************************
# round:  284
# current position (4, 13) action left
# next state (4, 12)
# *********************************************************
# round:  284
# current position (4, 12) action left
# next state (4, 11)
# *********************************************************
# round:  284
# current position (4, 11) action down
# next state (5, 11)
# *********************************************************
# round:  284
# current position (5, 11) action down
# next state (6, 11)
# *********************************************************
# round:  284
# current position (6, 11) action left
# next state (6, 10)
# *********************************************************
# round:  284
# current position (6, 10) action right
# next state (6, 11)
# *********************************************************
# round:  284
# current position (6, 11) action down
# next state (7, 11)
# *********************************************************
# round:  284
# current position (7, 11) action right
# next state (7, 12)
# *********************************************************
# round:  284
# current position (7, 12) action right
# next state (7, 13)
# *********************************************************
# round:  284
# current position (7, 13) action down
# next state (8, 13)
# *********************************************************
# round:  284
# current position (8, 13) action down
# next state (9, 13)
# *********************************************************
# round:  284
# current position (9, 13) action right
# next state (9, 14)
# *********************************************************
# round:  284
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  284
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  284
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  284
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  284
# current position (11, 14) action left
# next state (11, 13)
# *********************************************************
# round:  284
# current position (11, 13) action up
# next state (10, 13)
# *********************************************************
# round:  284
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  284
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  284
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  284
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  284
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  284
# current position (12, 14) action down
# next state (13, 14)
# *********************************************************
# round:  284
# current position (13, 14) action left
# next state (13, 13)
# *********************************************************
# round:  284
# current position (13, 13) action right
# next state (13, 14)
# *********************************************************
# round:  284
# current position (13, 14) action down
# next state (14, 14)
# *********************************************************
# round:  284
# round:  285
# current position (0, 0) action right
# next state (0, 1)
# *********************************************************
# round:  285
# current position (0, 1) action right
# next state (0, 2)
# *********************************************************
# round:  285
# current position (0, 2) action right
# next state (0, 3)
# *********************************************************
# round:  285
# current position (0, 3) action right
# next state (0, 4)
# *********************************************************
# round:  285
# current position (0, 4) action left
# next state (0, 3)
# *********************************************************
# round:  285
# current position (0, 3) action right
# next state (0, 4)
# *********************************************************
# round:  285
# current position (0, 4) action right
# next state (0, 5)
# *********************************************************
# round:  285
# current position (0, 5) action right
# next state (0, 6)
# *********************************************************
# round:  285
# current position (0, 6) action right
# next state (0, 7)
# *********************************************************
# round:  285
# current position (0, 7) action right
# next state (0, 8)
# *********************************************************
# round:  285
# current position (0, 8) action right
# next state (0, 9)
# *********************************************************
# round:  285
# current position (0, 9) action down
# next state (1, 9)
# *********************************************************
# round:  285
# current position (1, 9) action left
# next state (1, 8)
# *********************************************************
# round:  285
# current position (1, 8) action right
# next state (1, 9)
# *********************************************************
# round:  285
# current position (1, 9) action right
# next state (1, 10)
# *********************************************************
# round:  285
# current position (1, 10) action right
# next state (1, 11)
# *********************************************************
# round:  285
# current position (1, 11) action right
# next state (1, 12)
# *********************************************************
# round:  285
# current position (1, 12) action down
# next state (2, 12)
# *********************************************************
# round:  285
# current position (2, 12) action down
# next state (3, 12)
# *********************************************************
# round:  285
# current position (3, 12) action right
# next state (3, 13)
# *********************************************************
# round:  285
# current position (3, 13) action right
# next state (3, 14)
# *********************************************************
# round:  285
# current position (3, 14) action left
# next state (3, 13)
# *********************************************************
# round:  285
# current position (3, 13) action right
# next state (3, 14)
# *********************************************************
# round:  285
# current position (3, 14) action down
# next state (4, 14)
# *********************************************************
# round:  285
# current position (4, 14) action up
# next state (3, 14)
# *********************************************************
# round:  285
# current position (3, 14) action down
# next state (4, 14)
# *********************************************************
# round:  285
# current position (4, 14) action up
# next state (3, 14)
# *********************************************************
# round:  285
# current position (3, 14) action down
# next state (4, 14)
# *********************************************************
# round:  285
# current position (4, 14) action up
# next state (3, 14)
# *********************************************************
# round:  285
# current position (3, 14) action down
# next state (4, 14)
# *********************************************************
# round:  285
# current position (4, 14) action down
# next state (5, 14)
# *********************************************************
# round:  285
# current position (5, 14) action down
# next state (6, 14)
# *********************************************************
# round:  285
# current position (6, 14) action left
# next state (6, 13)
# *********************************************************
# round:  285
# current position (6, 13) action down
# next state (7, 13)
# *********************************************************
# round:  285
# current position (7, 13) action down
# next state (8, 13)
# *********************************************************
# round:  285
# current position (8, 13) action right
# next state (8, 14)
# *********************************************************
# round:  285
# current position (8, 14) action up
# next state (7, 14)
# *********************************************************
# round:  285
# current position (7, 14) action up
# next state (6, 14)
# *********************************************************
# round:  285
# current position (6, 14) action down
# next state (7, 14)
# *********************************************************
# round:  285
# current position (7, 14) action down
# next state (8, 14)
# *********************************************************
# round:  285
# current position (8, 14) action up
# next state (7, 14)
# *********************************************************
# round:  285
# current position (7, 14) action down
# next state (8, 14)
# *********************************************************
# round:  285
# current position (8, 14) action down
# next state (9, 14)
# *********************************************************
# round:  285
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  285
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  285
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  285
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  285
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  285
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  285
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  285
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  285
# current position (11, 14) action left
# next state (11, 13)
# *********************************************************
# round:  285
# current position (11, 13) action up
# next state (10, 13)
# *********************************************************
# round:  285
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  285
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  285
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  285
# current position (12, 14) action down
# next state (13, 14)
# *********************************************************
# round:  285
# current position (13, 14) action down
# next state (14, 14)
# *********************************************************
# round:  285
# round:  286
# current position (0, 0) action right
# next state (0, 1)
# *********************************************************
# round:  286
# current position (0, 1) action right
# next state (0, 2)
# *********************************************************
# round:  286
# current position (0, 2) action right
# next state (0, 3)
# *********************************************************
# round:  286
# current position (0, 3) action right
# next state (0, 4)
# *********************************************************
# round:  286
# current position (0, 4) action left
# next state (0, 3)
# *********************************************************
# round:  286
# current position (0, 3) action right
# next state (0, 4)
# *********************************************************
# round:  286
# current position (0, 4) action down
# next state (1, 4)
# *********************************************************
# round:  286
# current position (1, 4) action right
# next state (1, 5)
# *********************************************************
# round:  286
# current position (1, 5) action down
# next state (2, 5)
# *********************************************************
# round:  286
# current position (2, 5) action down
# next state (3, 5)
# *********************************************************
# round:  286
# current position (3, 5) action right
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action left
# next state (4, 5)
# *********************************************************
# round:  286
# current position (4, 5) action up
# next state (3, 5)
# *********************************************************
# round:  286
# current position (3, 5) action right
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action up
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action up
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action up
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action left
# next state (3, 5)
# *********************************************************
# round:  286
# current position (3, 5) action right
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action up
# next state (2, 6)
# *********************************************************
# round:  286
# current position (2, 6) action left
# next state (2, 5)
# *********************************************************
# round:  286
# current position (2, 5) action down
# next state (3, 5)
# *********************************************************
# round:  286
# current position (3, 5) action up
# next state (2, 5)
# *********************************************************
# round:  286
# current position (2, 5) action up
# next state (1, 5)
# *********************************************************
# round:  286
# current position (1, 5) action down
# next state (2, 5)
# *********************************************************
# round:  286
# current position (2, 5) action down
# next state (3, 5)
# *********************************************************
# round:  286
# current position (3, 5) action right
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action up
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action up
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action up
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action up
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action up
# next state (3, 6)
# *********************************************************
# round:  286
# current position (3, 6) action down
# next state (4, 6)
# *********************************************************
# round:  286
# current position (4, 6) action right
# next state (4, 7)
# *********************************************************
# round:  286
# current position (4, 7) action right
# next state (4, 8)
# *********************************************************
# round:  286
# current position (4, 8) action right
# next state (4, 9)
# *********************************************************
# round:  286
# current position (4, 9) action right
# next state (4, 10)
# *********************************************************
# round:  286
# current position (4, 10) action down
# next state (5, 10)
# *********************************************************
# round:  286
# current position (5, 10) action up
# next state (4, 10)
# *********************************************************
# round:  286
# current position (4, 10) action down
# next state (5, 10)
# *********************************************************
# round:  286
# current position (5, 10) action down
# next state (6, 10)
# *********************************************************
# round:  286
# current position (6, 10) action right
# next state (6, 11)
# *********************************************************
# round:  286
# current position (6, 11) action down
# next state (7, 11)
# *********************************************************
# round:  286
# current position (7, 11) action right
# next state (7, 12)
# *********************************************************
# round:  286
# current position (7, 12) action down
# next state (8, 12)
# *********************************************************
# round:  286
# current position (8, 12) action down
# next state (9, 12)
# *********************************************************
# round:  286
# current position (9, 12) action right
# next state (9, 13)
# *********************************************************
# round:  286
# current position (9, 13) action down
# next state (10, 13)
# *********************************************************
# round:  286
# current position (10, 13) action down
# next state (11, 13)
# *********************************************************
# round:  286
# current position (11, 13) action down
# next state (12, 13)
# *********************************************************
# round:  286
# current position (12, 13) action down
# next state (13, 13)
# *********************************************************
# round:  286
# current position (13, 13) action down
# next state (14, 13)
# *********************************************************
# round:  286
# current position (14, 13) action right
# next state (14, 14)
# *********************************************************
# round:  286
# round:  287
# current position (0, 0) action right
# next state (0, 1)
# *********************************************************
# round:  287
# current position (0, 1) action right
# next state (0, 2)
# *********************************************************
# round:  287
# current position (0, 2) action right
# next state (0, 3)
# *********************************************************
# round:  287
# current position (0, 3) action down
# next state (1, 3)
# *********************************************************
# round:  287
# current position (1, 3) action up
# next state (0, 3)
# *********************************************************
# round:  287
# current position (0, 3) action down
# next state (1, 3)
# *********************************************************
# round:  287
# current position (1, 3) action right
# next state (1, 4)
# *********************************************************
# round:  287
# current position (1, 4) action down
# next state (2, 4)
# *********************************************************
# round:  287
# current position (2, 4) action right
# next state (2, 5)
# *********************************************************
# round:  287
# current position (2, 5) action down
# next state (3, 5)
# *********************************************************
# round:  287
# current position (3, 5) action right
# next state (3, 6)
# *********************************************************
# round:  287
# current position (3, 6) action up
# next state (2, 6)
# *********************************************************
# round:  287
# current position (2, 6) action left
# next state (2, 5)
# *********************************************************
# round:  287
# current position (2, 5) action down
# next state (3, 5)
# *********************************************************
# round:  287
# current position (3, 5) action right
# next state (3, 6)
# *********************************************************
# round:  287
# current position (3, 6) action up
# next state (2, 6)
# *********************************************************
# round:  287
# current position (2, 6) action right
# next state (2, 7)
# *********************************************************
# round:  287
# current position (2, 7) action up
# next state (1, 7)
# *********************************************************
# round:  287
# current position (1, 7) action up
# next state (0, 7)
# *********************************************************
# round:  287
# current position (0, 7) action right
# next state (0, 8)
# *********************************************************
# round:  287
# current position (0, 8) action right
# next state (0, 9)
# *********************************************************
# round:  287
# current position (0, 9) action left
# next state (0, 8)
# *********************************************************
# round:  287
# current position (0, 8) action right
# next state (0, 9)
# *********************************************************
# round:  287
# current position (0, 9) action right
# next state (0, 10)
# *********************************************************
# round:  287
# current position (0, 10) action right
# next state (0, 11)
# *********************************************************
# round:  287
# current position (0, 11) action down
# next state (1, 11)
# *********************************************************
# round:  287
# current position (1, 11) action right
# next state (1, 12)
# *********************************************************
# round:  287
# current position (1, 12) action down
# next state (2, 12)
# *********************************************************
# round:  287
# current position (2, 12) action down
# next state (3, 12)
# *********************************************************
# round:  287
# current position (3, 12) action right
# next state (3, 13)
# *********************************************************
# round:  287
# current position (3, 13) action left
# next state (3, 12)
# *********************************************************
# round:  287
# current position (3, 12) action down
# next state (4, 12)
# *********************************************************
# round:  287
# current position (4, 12) action down
# next state (5, 12)
# *********************************************************
# round:  287
# current position (5, 12) action down
# next state (6, 12)
# *********************************************************
# round:  287
# current position (6, 12) action down
# next state (7, 12)
# *********************************************************
# round:  287
# current position (7, 12) action down
# next state (8, 12)
# *********************************************************
# round:  287
# current position (8, 12) action up
# next state (7, 12)
# *********************************************************
# round:  287
# current position (7, 12) action right
# next state (7, 13)
# *********************************************************
# round:  287
# current position (7, 13) action down
# next state (8, 13)
# *********************************************************
# round:  287
# current position (8, 13) action down
# next state (9, 13)
# *********************************************************
# round:  287
# current position (9, 13) action right
# next state (9, 14)
# *********************************************************
# round:  287
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action up
# next state (9, 14)
# *********************************************************
# round:  287
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  287
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  287
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  287
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action left
# next state (11, 13)
# *********************************************************
# round:  287
# current position (11, 13) action up
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action up
# next state (9, 14)
# *********************************************************
# round:  287
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  287
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action up
# next state (9, 13)
# *********************************************************
# round:  287
# current position (9, 13) action right
# next state (9, 14)
# *********************************************************
# round:  287
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action down
# next state (12, 14)
# *********************************************************
# round:  287
# current position (12, 14) action up
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action left
# next state (11, 13)
# *********************************************************
# round:  287
# current position (11, 13) action up
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action up
# next state (9, 14)
# *********************************************************
# round:  287
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action up
# next state (9, 14)
# *********************************************************
# round:  287
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  287
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action left
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action left
# next state (10, 12)
# *********************************************************
# round:  287
# current position (10, 12) action right
# next state (10, 13)
# *********************************************************
# round:  287
# current position (10, 13) action right
# next state (10, 14)
# *********************************************************
# round:  287
# current position (10, 14) action up
# next state (9, 14)
# *********************************************************
# round:  287
# current position (9, 14) action down
# next state (10, 14)
# ...
# round:  297
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  297
# current position (10, 14) action up
# next state (9, 14)
# *********************************************************
# round:  297
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  297
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  297
# current position (11, 14) action up
# next state (10, 14)
# *********************************************************
# round:  297
# current position (10, 14) action up
# next state (9, 14)
# *********************************************************
# round:  297
# current position (9, 14) action up
# next state (8, 14)
# *********************************************************
# round:  297
# current position (8, 14) action down
# next state (9, 14)
# *********************************************************
# round:  297
# current position (9, 14) action down
# next state (10, 14)
# *********************************************************
# round:  297
# current position (10, 14) action down
# next state (11, 14)
# *********************************************************
# round:  297
# current position (11, 14) action left
# next state (11, 13)
# *********************************************************
# round:  297
# current position (11, 13) action down
# next state (12, 13)
# *********************************************************
# round:  297
# current position (12, 13) action down
# next state (13, 13)
# *********************************************************
# round:  297
# current position (13, 13) action down
# next state (14, 13)
# *********************************************************
# round:  297
# current position (14, 13) action right
# next state (14, 14)
# *********************************************************
# round:  297
# round:  298
# current position (0, 0) action down
# next state (1, 0)
# *********************************************************
# round:  298
# current position (1, 0) action down
# next state (2, 0)
# *********************************************************
# round:  298
# current position (2, 0) action right
# next state (2, 1)
# *********************************************************
# round:  298
# current position (2, 1) action down
# next state (3, 1)
# *********************************************************
# round:  298
# current position (3, 1) action left
# next state (3, 0)
# *********************************************************
# round:  298
# current position (3, 0) action up
# next state (2, 0)
# *********************************************************
# round:  298
# current position (2, 0) action down
# next state (3, 0)
# *********************************************************
# round:  298
# current position (3, 0) action down
# next state (4, 0)
# *********************************************************
# round:  298
# current position (4, 0) action down
# next state (5, 0)
# *********************************************************
# round:  298
# current position (5, 0) action right
# next state (5, 1)
# *********************************************************
# round:  298
# current position (5, 1) action up
# next state (4, 1)
# *********************************************************
# round:  298
# current position (4, 1) action down
# next state (5, 1)
# *********************************************************
# round:  298
# current position (5, 1) action right
# next state (5, 2)
# *********************************************************
# round:  298
# current position (5, 2) action right
# next state (5, 3)
# *********************************************************
# round:  298
# current position (5, 3) action down
# next state (6, 3)
# *********************************************************
# round:  298
# current position (6, 3) action left
# next state (6, 2)
# *********************************************************
# round:  298
# current position (6, 2) action up
# next state (5, 2)
# *********************************************************
# round:  298
# current position (5, 2) action right
# next state (5, 3)
# *********************************************************
# round:  298
# current position (5, 3) action right
# next state (5, 4)
# *********************************************************
# round:  298
# current position (5, 4) action down
# next state (6, 4)
# *********************************************************
# round:  298
# current position (6, 4) action down
# next state (7, 4)
# *********************************************************
# round:  298
# current position (7, 4) action down
# next state (8, 4)
# *********************************************************
# round:  298
# current position (8, 4) action down
# next state (9, 4)
# *********************************************************
# round:  298
# current position (9, 4) action right
# next state (9, 5)
# *********************************************************
# round:  298
# current position (9, 5) action up
# next state (8, 5)
# *********************************************************
# round:  298
# current position (8, 5) action left
# next state (8, 4)
# *********************************************************
# round:  298
# current position (8, 4) action down
# next state (9, 4)
# *********************************************************
# round:  298
# current position (9, 4) action right
# next state (9, 5)
# *********************************************************
# round:  298
# current position (9, 5) action right
# next state (9, 6)
# *********************************************************
# round:  298
# current position (9, 6) action up
# next state (8, 6)
# *********************************************************
# round:  298
# current position (8, 6) action left
# next state (8, 5)
# *********************************************************
# round:  298
# current position (8, 5) action right
# next state (8, 6)
# *********************************************************
# round:  298
# current position (8, 6) action down
# next state (9, 6)
# *********************************************************
# round:  298
# current position (9, 6) action down
# next state (10, 6)
# *********************************************************
# round:  298
# current position (10, 6) action up
# next state (9, 6)
# *********************************************************
# round:  298
# current position (9, 6) action down
# next state (10, 6)
# *********************************************************
# round:  298
# current position (10, 6) action right
# next state (10, 7)
# *********************************************************
# round:  298
# current position (10, 7) action down
# next state (11, 7)
# *********************************************************
# round:  298
# current position (11, 7) action right
# next state (11, 8)
# *********************************************************
# round:  298
# current position (11, 8) action left
# next state (11, 7)
# *********************************************************
# round:  298
# current position (11, 7) action right
# next state (11, 8)
# *********************************************************
# round:  298
# current position (11, 8) action up
# next state (10, 8)
# *********************************************************
# round:  298
# current position (10, 8) action up
# next state (9, 8)
# *********************************************************
# round:  298
# current position (9, 8) action down
# next state (10, 8)
# *********************************************************
# round:  298
# current position (10, 8) action up
# next state (9, 8)
# *********************************************************
# round:  298
# current position (9, 8) action left
# next state (9, 7)
# *********************************************************
# round:  298
# current position (9, 7) action down
# next state (10, 7)
# *********************************************************
# round:  298
# current position (10, 7) action down
# next state (11, 7)
# *********************************************************
# round:  298
# current position (11, 7) action down
# next state (12, 7)
# *********************************************************
# round:  298
# current position (12, 7) action right
# next state (12, 8)
# *********************************************************
# round:  298
# current position (12, 8) action right
# next state (12, 9)
# *********************************************************
# round:  298
# current position (12, 9) action right
# next state (12, 10)
# *********************************************************
# round:  298
# current position (12, 10) action left
# next state (12, 9)
# *********************************************************
# round:  298
# current position (12, 9) action right
# next state (12, 10)
# *********************************************************
# round:  298
# current position (12, 10) action right
# next state (12, 11)
# *********************************************************
# round:  298
# current position (12, 11) action down
# next state (13, 11)
# *********************************************************
# round:  298
# current position (13, 11) action right
# next state (13, 12)
# *********************************************************
# round:  298
# current position (13, 12) action down
# next state (14, 12)
# *********************************************************
# round:  298
# current position (14, 12) action right
# next state (14, 13)
# *********************************************************
# round:  298
# current position (14, 13) action right
# next state (14, 14)
# *********************************************************
# round:  298
# round:  299
# current position (0, 0) action down
# next state (1, 0)
# *********************************************************
# round:  299
# current position (1, 0) action right
# next state (1, 1)
# *********************************************************
# round:  299
# current position (1, 1) action down
# next state (2, 1)
# *********************************************************
# round:  299
# current position (2, 1) action up
# next state (1, 1)
# *********************************************************
# round:  299
# current position (1, 1) action right
# next state (1, 2)
# *********************************************************
# round:  299
# current position (1, 2) action left
# next state (1, 1)
# *********************************************************
# round:  299
# current position (1, 1) action right
# next state (1, 2)
# *********************************************************
# round:  299
# current position (1, 2) action down
# next state (2, 2)
# *********************************************************
# round:  299
# current position (2, 2) action down
# next state (3, 2)
# *********************************************************
# round:  299
# current position (3, 2) action down
# next state (4, 2)
# *********************************************************
# round:  299
# current position (4, 2) action down
# next state (5, 2)
# *********************************************************
# round:  299
# current position (5, 2) action right
# next state (5, 3)
# *********************************************************
# round:  299
# current position (5, 3) action down
# next state (6, 3)
# *********************************************************
# round:  299
# current position (6, 3) action down
# next state (7, 3)
# *********************************************************
# round:  299
# current position (7, 3) action right
# next state (7, 4)
# *********************************************************
# round:  299
# current position (7, 4) action up
# next state (6, 4)
# *********************************************************
# round:  299
# current position (6, 4) action down
# next state (7, 4)
# *********************************************************
# round:  299
# current position (7, 4) action left
# next state (7, 3)
# *********************************************************
# round:  299
# current position (7, 3) action left
# next state (7, 2)
# *********************************************************
# round:  299
# current position (7, 2) action down
# next state (8, 2)
# *********************************************************
# round:  299
# current position (8, 2) action down
# next state (9, 2)
# *********************************************************
# round:  299
# current position (9, 2) action right
# next state (9, 3)
# *********************************************************
# round:  299
# current position (9, 3) action down
# next state (10, 3)
# *********************************************************
# round:  299
# current position (10, 3) action right
# next state (10, 4)
# *********************************************************
# round:  299
# current position (10, 4) action up
# next state (9, 4)
# *********************************************************
# round:  299
# current position (9, 4) action up
# next state (8, 4)
# *********************************************************
# round:  299
# current position (8, 4) action down
# next state (9, 4)
# *********************************************************
# round:  299
# current position (9, 4) action right
# next state (9, 5)
# *********************************************************
# round:  299
# current position (9, 5) action right
# next state (9, 6)
# *********************************************************
# round:  299
# current position (9, 6) action right
# next state (9, 7)
# *********************************************************
# round:  299
# current position (9, 7) action down
# next state (10, 7)
# *********************************************************
# round:  299
# current position (10, 7) action down
# next state (11, 7)
# *********************************************************
# round:  299
# current position (11, 7) action down
# next state (12, 7)
# *********************************************************
# round:  299
# current position (12, 7) action right
# next state (12, 8)
# *********************************************************
# round:  299
# current position (12, 8) action up
# next state (11, 8)
# *********************************************************
# round:  299
# current position (11, 8) action down
# next state (12, 8)
# *********************************************************
# round:  299
# current position (12, 8) action down
# next state (13, 8)
# *********************************************************
# round:  299
# current position (13, 8) action up
# next state (12, 8)
# *********************************************************
# round:  299
# current position (12, 8) action down
# next state (13, 8)
# *********************************************************
# round:  299
# current position (13, 8) action right
# next state (13, 9)
# *********************************************************
# round:  299
# current position (13, 9) action down
# next state (14, 9)
# *********************************************************
# round:  299
# current position (14, 9) action right
# next state (14, 10)
# *********************************************************
# round:  299
# current position (14, 10) action right
# next state (14, 11)
# *********************************************************
# round:  299
# current position (14, 11) action right
# next state (14, 12)
# *********************************************************
# round:  299
# current position (14, 12) action up
# next state (13, 12)
# *********************************************************
# round:  299
# current position (13, 12) action down
# next state (14, 12)
# *********************************************************
# round:  299
# current position (14, 12) action left
# next state (14, 11)
# *********************************************************
# round:  299
# current position (14, 11) action right
# next state (14, 12)
# *********************************************************
# round:  299
# current position (14, 12) action right
# next state (14, 13)
# *********************************************************
# round:  299
# current position (14, 13) action up
# next state (13, 13)
# *********************************************************
# round:  299
# current position (13, 13) action down
# next state (14, 13)
# *********************************************************
# round:  299
# current position (14, 13) action right
# next state (14, 14)
# *********************************************************
# round:  299

# %% [markdown]
# #### Final Q Table after Learning

# %%
path_agent.Q_values
# Out:
# {(0, 0): {'down': 5.761724461315501,
#   'left': -inf,
#   'right': 5.611545700164578,
#   'up': -inf},
#  (0, 1): {'down': 5.590129516783536,
#   'left': 4.918711963759904,
#   'right': 5.563215383418943,
#   'up': -inf},
#  (0, 2): {'down': 5.858506797938513,
#   'left': 4.797233911420093,
#   'right': 5.337884769176371,
#   'up': -inf},
#  (0, 3): {'down': 4.458214213406895,
#   'left': 4.829784981742641,
#   'right': 4.707171565086403,
#   'up': -inf},
#  (0, 4): {'down': -0.20645295037955405,
#   'left': 4.359040081032669,
#   'right': 5.931719206591738,
#   'up': -inf},
#  (0, 5): {'down': 5.753919490123955,
#   'left': 4.388146480746764,
#   'right': 5.876156050605844,
#   'up': -inf},
#  (0, 6): {'down': 5.674523556252256,
#   'left': 4.597017295340026,
#   'right': 5.805875272034567,
#   'up': -inf},
#  (0, 7): {'down': 4.788422051835729,
#   'left': 4.903382146573093,
#   'right': 5.831486532266529,
#   'up': -inf},
#  (0, 8): {'down': 5.57179058840182,
#   'left': 4.485148215461928,
#   'right': 5.618641669617038,
#   'up': -inf},
#  (0, 9): {'down': 5.460251154459306,
#   'left': 4.92016296559935,
#   'right': 5.812675518712093,
#   'up': -inf},
#  (0, 10): {'down': 5.416960672799198,
#   'left': 4.680996195948009,
#   'right': 5.931598288764034,
#   'up': -inf},
#  (0, 11): {'down': 5.900714233664459,
#   'left': 4.870578701394523,
#   'right': 5.762136998451882,
#   'up': -inf},
#  (0, 12): {'down': 5.846958943320803,
#   'left': 4.4864645524341915,
#   'right': 5.688472689275541,
#   'up': -inf},
#  (0, 13): {'down': 5.835472915110532,
#   'left': 4.70595228260593,
#   'right': 5.688935225185892,
#   'up': -inf},
#  (0, 14): {'down': 5.649688148211215,
#   'left': 4.869982974043838,
#   'right': -inf,
#   'up': -inf},
#  (1, 0): {'down': 5.164655292493886,
#   'left': -inf,
#   'right': 5.643733433215694,
#   'up': 4.91946887497291},
#  (1, 1): {'down': 5.286810951360761,
#   'left': 4.801908242679378,
#   'right': 5.51814839646006,
#   'up': 4.7552438895372084},
#  (1, 2): {'down': 5.566891861758784,
#   'left': 4.795939365091471,
#   'right': 4.573289750680386,
#   'up': 4.517981199822675},
#  (1, 3): {'down': -0.4056638023638369,
#   'left': 4.1840107096437205,
#   'right': -0.5129571757387907,
#   'up': 4.2594878942667025},
#  (1, 4): {'down': 4.943921967313043,
#   'left': 4.227062333249292,
#   'right': 5.752457888220822,
#   'up': 4.63465481740269},
#  (1, 5): {'down': 5.70911687304543,
#   'left': -0.9013093695633814,
#   'right': 5.068633250129784,
#   'up': 4.861138171054957},
#  (1, 6): {'down': 3.5811258497709426,
#   'left': 4.487754017154927,
#   'right': 5.2781735194729515,
#   'up': 4.822604394642473},
#  (1, 7): {'down': -0.8985893716328615,
#   'left': 4.392695835325887,
#   'right': 3.82085095804529,
#   'up': 4.867094164581907},
#  (1, 8): {'down': -1.04665541669853,
#   'left': 4.681352611516122,
#   'right': 5.713151842017678,
#   'up': 4.480815788901352},
#  (1, 9): {'down': 3.204076521770662,
#   'left': 4.868220335293373,
#   'right': 5.827389154876809,
#   'up': 4.629778139831},
#  (1, 10): {'down': 5.503629225499943,
#   'left': 4.0095846932937915,
#   'right': 5.907788792310913,
#   'up': 4.890982984199333},
#  (1, 11): {'down': 5.58848225066049,
#   'left': 4.882648590690423,
#   'right': 5.898748548694133,
#   'up': 4.777061057965712},
#  (1, 12): {'down': 5.867659782967465,
#   'left': 4.29621680336106,
#   'right': 5.49228258485497,
#   'up': 4.260382328302343},
#  (1, 13): {'down': 5.383648587668906,
 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (8, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (8, 2): {'down': 2.4883669498123555,
#   'left': 0,
#   'right': 5.83630308681006,
#   'up': 0},
#  (8, 3): {'down': 2.7069979096264642,
#   'left': 4.627257475899791,
#   'right': 5.713593000042602,
#   'up': 4.5146860233972035},
#  (8, 4): {'down': 5.786601466528672,
#   'left': 4.8852873558258905,
#   'right': 5.294902243353352,
#   'up': 4.709036512161558},
#  (8, 5): {'down': 5.420846260269835,
#   'left': 4.827090611860996,
#   'right': 5.842886661061039,
#   'up': 3.801521905140639},
#  (8, 6): {'down': 5.727447488483936,
#   'left': 4.760418007598608,
#   'right': 5.440779858391841,
#   'up': 4.6686438306835},
#  (8, 7): {'down': 5.8410044798938845,
#   'left': 4.197477730027777,
#   'right': 4.905138453623719,
#   'up': 4.363128679409992},
#  (8, 8): {'down': 5.707241640614126,
#   'left': 3.802820714355442,
#   'right': 4.647514766874611,
#   'up': 3.8453980443860543},
#  (8, 9): {'down': 0,
#   'left': 2.7918248161337593,
#   'right': 2.7962318185036343,
#   'up': 0},
#  (8, 10): {'down': -1.1142692928874833,
#   'left': 4.389586559504019,
#   'right': 5.374382580316479,
#   'up': 4.4880451012931095},
#  (8, 11): {'down': -3.227391991064194,
#   'left': 4.514273074874218,
#   'right': 5.814590420251005,
#   'up': 4.840721690671203},
#  (8, 12): {'down': -0.13449630351936195,
#   'left': 4.599949666783851,
#   'right': 5.479626850226301,
#   'up': 4.113537799560725},
#  (8, 13): {'down': 5.5285185603435885,
#   'left': 4.684093355759181,
#   'right': 5.354851108624891,
#   'up': 4.558650885566329},
#  (8, 14): {'down': 5.758237717111948,
#   'left': 4.608426184248329,
#   'right': -inf,
#   'up': 4.672836085054353},
#  (9, 0): {'down': 0, 'left': -inf, 'right': 0, 'up': 0},
#  (9, 1): {'down': 0, 'left': 0, 'right': 0, 'up': 0},
#  (9, 2): {'down': 0, 'left': 0, 'right': 2.294556499374518, 'up': 0},
#  (9, 3): {'down': 1.6485216645817269,
#   'left': 0,
#   'right': 2.606163571127973,
#   'up': 4.6115722126071255},
#  (9, 4): {'down': -0.9904115110106777,
#   'left': 4.007018736810211,
#   'right': 5.663460676457949,
#   'up': 4.534154254035838},
#  (9, 5): {'down': 5.063724636408638,
#   'left': 4.314297919887209,
#   'right': 5.661707103911349,
#   'up': 4.585923965431975},
#  (9, 6): {'down': 5.5939526113467934,
#   'left': 4.488869288567314,
#   'right': 5.778506446124941,
#   'up': 4.596496167954595},
#  (9, 7): {'down': 5.844823673298569,
#   'left': 4.853437352806572,
#   'right': 4.9602483132036825,
#   'up': 4.715149917386638},
#  (9, 8): {'down': 5.516147667946518,
#   'left': 4.807648519174419,
#   'right': -0.825192404530023,
#   'up': 3.7591234269360783},
#  (9, 9): {'down': 0,
#   'left': 4.595327469022722,
#   'right': -0.9252445137752305,
#   'up': 0},
#  (9, 10): {'down': 5.718134073193509,
#   'left': -1.8241486829531914,
#   'right': -3.0185101113965795,
#   'up': 2.8123147740949435},
#  (9, 11): {'down': 5.185062791648044,
#   'left': -3.5403228352306026,
{'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 5): {'down': -inf, 'left': 0, 'right': 0, 'up': 0},
#  (14, 6): {'down': -inf, 'left': 0, 'right': 3.213685264086304, 'up': 0},
#  (14, 7): {'down': -inf,
#   'left': 2.164105579225891,
#   'right': 0,
#   'up': 4.712284213621013},
#  (14, 8): {'down': -inf,
#   'left': 3.29263323808718,
#   'right': 5.262851436671555,
#   'up': 2.852253968239913},
#  (14, 9): {'down': -inf,
#   'left': 3.6936487584795756,
#   'right': 5.891850130143046,
#   'up': 3.716729218482195},
#  (14, 10): {'down': -inf,
#   'left': 4.65473479810405,
#   'right': 5.777680492201804,
#   'up': 4.130619018525412},
#  (14, 11): {'down': -inf,
#   'left': 4.915015189284817,
#   'right': 5.827616791956459,
#   'up': 4.3577289269544215},
#  (14, 12): {'down': -inf,
#   'left': 4.928863963977006,
#   'right': 6.694252829014038,
#   'up': 4.949983564693483},
#  (14, 13): {'down': -inf,
#   'left': 5.826612417592081,
#   'right': 10.0,
#   'up': 5.938456204957824},
#  (14, 14): {'down': -inf, 'left': 0, 'right': -inf, 'up': 0}}

# %% [markdown]
# ### Result

# %% [markdown]
# #### Optimal Path from Q Table

# %%
route = path_agent.get_result_path()
# Out:
# current position:  (0, 0)
# current position:  (1, 0)
# current position:  (1, 1)
# current position:  (1, 2)
# current position:  (2, 2)
# current position:  (3, 2)
# current position:  (4, 2)
# current position:  (5, 2)
# current position:  (5, 3)
# current position:  (6, 3)
# current position:  (7, 3)
# current position:  (7, 4)
# current position:  (8, 4)
# current position:  (9, 4)
# current position:  (9, 5)
# current position:  (9, 6)
# current position:  (9, 7)
# current position:  (10, 7)
# current position:  (11, 7)
# current position:  (12, 7)
# current position:  (12, 8)
# current position:  (12, 9)
# current position:  (13, 9)
# current position:  (14, 9)
# current position:  (14, 10)
# current position:  (14, 11)
# current position:  (14, 12)
# current position:  (14, 13)

# %% [markdown]
# #### Agenet Learned Path Visualization
# p: path
# x: obstacles
# G: goal

# %%
path_agent.boardState.printPath(route)
# Out:
# --------------------------------------------------------------
# | p |   |   |   |   |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# | p | p | p |   | x |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   | p | x |   |   |   | x | x |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   | x | p |   |   |   |   | x |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# | x |   | p |   |   | x |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   | p | p |   | x |   |   |   |   |   |   | x | x | x |
# --------------------------------------------------------------
# |   |   |   | p |   | x | x |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   | p | p |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   | p |   |   |   |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   | p | p | p | p |   | x | x | x | x |   |   |
# --------------------------------------------------------------
# | x | x |   |   | x |   |   | p |   |   |   |   |   |   |   |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   | p |   |   |   |   | x |   |   |
# --------------------------------------------------------------
# |   |   |   |   | x |   |   | p | p | p |   |   |   | x |   |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   |   |   | p |   |   |   |   | x |
# --------------------------------------------------------------
# |   |   |   |   |   |   |   |   |   | p | p | p | p | p | G |
# --------------------------------------------------------------

# %% [markdown]
# #### Runtime per Round in seconds
# The runtime drastically decrease after the first few rounds.

# %%
path_agent.plot_runtime()

# %% [markdown]
# #### Total Number of Travelled States per Round
# Similar as runtime, the total number of states the agenet needs to explore before reaching the goal state drastically decreases after the first few rounds.

# %%
path_agent.plot_states_num_per_round()
